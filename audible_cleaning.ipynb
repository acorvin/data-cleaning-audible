# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv(r"audible_uncleaned.csv")
df
# Out:
#                                              name                     author  \
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# 87484                   Last Days of the Bus Club     Writtenby:ChrisStewart
# 87485                                    The Alps    Writtenby:StephenO'Shea
# 87486                        The Innocents Abroad        Writtenby:MarkTwain
# 87487                       A Sentimental Journey   Writtenby:LaurenceSterne
# 87488                                      Havana    Writtenby:MarkKurlansky
#
# ...

# %%
# Remove any duplicates from the dataset
df = df.drop_duplicates()
df
# Out:
#                                              name                     author  \
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# 87484                   Last Days of the Bus Club     Writtenby:ChrisStewart
# 87485                                    The Alps    Writtenby:StephenO'Shea
# 87486                        The Innocents Abroad        Writtenby:MarkTwain
# 87487                       A Sentimental Journey   Writtenby:LaurenceSterne
# 87488                                      Havana    Writtenby:MarkKurlansky
#
# ...

# %%
# Remove extraneous strings in author column
df['author'] = df['author'].str.lstrip('Writtenby:')
df
# Out:
#                                              name           author  \
# 0                      Geronimo Stilton #11 & #12  GeronimoStilton
# 1                                The Burning Maze      RickRiordan
# 2                                    The Deep End       JeffKinney
# 3                            Daughter of the Deep      RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      RickRiordan
# ...                                           ...              ...
# 87484                   Last Days of the Bus Club     ChrisStewart
# 87485                                    The Alps    StephenO'Shea
# 87486                        The Innocents Abroad        MarkTwain
# 87487                       A Sentimental Journey   LaurenceSterne
# 87488                                      Havana    MarkKurlansky
#
#                         narrator                time releasedate language  \
# 0          Narratedby:BillLobely   2 hrs and 20 mins    04-08-08  English
# ...

# %%
# Add a space between author first and last name
df['author'] = df['author'].str.replace(r"(?<=[a-z])(?=[A-Z])", " ",regex=True)
df
# Out:
#                                              name            author  \
# 0                      Geronimo Stilton #11 & #12  Geronimo Stilton
# 1                                The Burning Maze      Rick Riordan
# 2                                    The Deep End       Jeff Kinney
# 3                            Daughter of the Deep      Rick Riordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Rick Riordan
# ...                                           ...               ...
# 87484                   Last Days of the Bus Club     Chris Stewart
# 87485                                    The Alps    Stephen O'Shea
# 87486                        The Innocents Abroad        Mark Twain
# 87487                       A Sentimental Journey   Laurence Sterne
# 87488                                      Havana    Mark Kurlansky
#
#                         narrator                time releasedate language  \
# 0          Narratedby:BillLobely   2 hrs and 20 mins    04-08-08  English
# ...

# %%
# Remove extraneous strings in narrator column
df['narrator'] = df['narrator'].str.lstrip('Narratedby:')
df
# Out:
#                                              name            author  \
# 0                      Geronimo Stilton #11 & #12  Geronimo Stilton
# 1                                The Burning Maze      Rick Riordan
# 2                                    The Deep End       Jeff Kinney
# 3                            Daughter of the Deep      Rick Riordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Rick Riordan
# ...                                           ...               ...
# 87484                   Last Days of the Bus Club     Chris Stewart
# 87485                                    The Alps    Stephen O'Shea
# 87486                        The Innocents Abroad        Mark Twain
# 87487                       A Sentimental Journey   Laurence Sterne
# 87488                                      Havana    Mark Kurlansky
#
#              narrator                time releasedate language  \
# 0          BillLobely   2 hrs and 20 mins    04-08-08  English
# ...

# %%
# Add a space between narrator first and last name
df['narrator'] = df['narrator'].str.replace(r"(?<=[a-z])(?=[A-Z])", " ",regex=True)
df
# Out:
#                                              name            author  \
# 0                      Geronimo Stilton #11 & #12  Geronimo Stilton
# 1                                The Burning Maze      Rick Riordan
# 2                                    The Deep End       Jeff Kinney
# 3                            Daughter of the Deep      Rick Riordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Rick Riordan
# ...                                           ...               ...
# 87484                   Last Days of the Bus Club     Chris Stewart
# 87485                                    The Alps    Stephen O'Shea
# 87486                        The Innocents Abroad        Mark Twain
# 87487                       A Sentimental Journey   Laurence Sterne
# 87488                                      Havana    Mark Kurlansky
#
#               narrator                time releasedate language  \
# 0          Bill Lobely   2 hrs and 20 mins    04-08-08  English
# ...

# %%
# Extract star rating from stars column and convert it to a float
df['star_rating'] = df['stars'].str.extract(r'(\d+\.\d+|\d+)').astype('float')
df
# Out:
#                                              name            author  \
# 0                      Geronimo Stilton #11 & #12  Geronimo Stilton
# 1                                The Burning Maze      Rick Riordan
# 2                                    The Deep End       Jeff Kinney
# 3                            Daughter of the Deep      Rick Riordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Rick Riordan
# ...                                           ...               ...
# 87484                   Last Days of the Bus Club     Chris Stewart
# 87485                                    The Alps    Stephen O'Shea
# 87486                        The Innocents Abroad        Mark Twain
# 87487                       A Sentimental Journey   Laurence Sterne
# 87488                                      Havana    Mark Kurlansky
#
#               narrator                time releasedate language  \
# 0          Bill Lobely   2 hrs and 20 mins    04-08-08  English
# ...

# %%
# Drop rows of movies that have not been rated
df = df[df['stars'] != 'Not rated yet']
df.reset_index(drop=True, inplace=True)
df
# Out:
#                                              name             author  \
# 0                      Geronimo Stilton #11 & #12   Geronimo Stilton
# 1                                The Burning Maze       Rick Riordan
# 2                                    The Deep End        Jeff Kinney
# 3                            Daughter of the Deep       Rick Riordan
# 4      The Lightning Thief: Percy Jackson, Book 1       Rick Riordan
# ...                                           ...                ...
# 15067                                  Why We Fly          Evan Rail
# 15068                                  River Town      Peter Hessler
# 15069                      Figures in a Landscape       Paul Theroux
# 15070                             Tower of London              Minds
# 15071                          Tigers in the Snow  Peter Matthiessen
#
#                 narrator                time releasedate language  \
# 0            Bill Lobely   2 hrs and 20 mins    04-08-08  English
# ...

# %%
# Drop the stars and price columns. They will not be used.
df = df.drop(columns = ['stars', 'price'])
df
# Out:
#                                              name             author  \
# 0                      Geronimo Stilton #11 & #12   Geronimo Stilton
# 1                                The Burning Maze       Rick Riordan
# 2                                    The Deep End        Jeff Kinney
# 3                            Daughter of the Deep       Rick Riordan
# 4      The Lightning Thief: Percy Jackson, Book 1       Rick Riordan
# ...                                           ...                ...
# 15067                                  Why We Fly          Evan Rail
# 15068                                  River Town      Peter Hessler
# 15069                      Figures in a Landscape       Paul Theroux
# 15070                             Tower of London              Minds
# 15071                          Tigers in the Snow  Peter Matthiessen
#
#                 narrator                time releasedate language  star_rating
# ...

# %%
# Convert the releasedate column datetime format
df['releasedate'] = pd.to_datetime(df['releasedate'], format='%d-%m-%y')
df['releasedate'] = df['releasedate'].dt.strftime('%Y-%m-%d')
df
# Out:
#                                              name             author  \
# 0                      Geronimo Stilton #11 & #12   Geronimo Stilton
# 1                                The Burning Maze       Rick Riordan
# 2                                    The Deep End        Jeff Kinney
# 3                            Daughter of the Deep       Rick Riordan
# 4      The Lightning Thief: Percy Jackson, Book 1       Rick Riordan
# ...                                           ...                ...
# 15067                                  Why We Fly          Evan Rail
# 15068                                  River Town      Peter Hessler
# 15069                      Figures in a Landscape       Paul Theroux
# 15070                             Tower of London              Minds
# 15071                          Tigers in the Snow  Peter Matthiessen
#
#                 narrator                time releasedate language  star_rating
# ...

# %%
# Extract hours and minutes as integers
hours_extracted = df['time'].str.extract(r'(\d+) hrs?')
minutes_extracted = df['time'].str.extract(r'(\d+) mins?')

# Convert hours and minutes to integers, filling NaN values with 0
df['hours'] = hours_extracted[0].fillna(0).astype(int)
df['minutes'] = minutes_extracted[0].fillna(0).astype(int)

# Calculate total time in minutes
df['total_minutes'] = df['hours'] * 60 + df['minutes']

# Convert total time in minutes to HH:MM:SS format
df['duration'] = df['total_minutes'].apply(lambda x: f"{x // 60:02d}:{x % 60:02d}:00")

# Drop intermediate and unused columns if needed
df.drop(['hours', 'minutes', 'total_minutes', 'time'], axis=1, inplace=True)
df
# Out:
#                                              name             author  \
# 0                      Geronimo Stilton #11 & #12   Geronimo Stilton
# 1                                The Burning Maze       Rick Riordan
# 2                                    The Deep End        Jeff Kinney
# 3                            Daughter of the Deep       Rick Riordan
# 4      The Lightning Thief: Percy Jackson, Book 1       Rick Riordan
# ...                                           ...                ...
# 15067                                  Why We Fly          Evan Rail
# 15068                                  River Town      Peter Hessler
# 15069                      Figures in a Landscape       Paul Theroux
# 15070                             Tower of London              Minds
# 15071                          Tigers in the Snow  Peter Matthiessen
#
#                 narrator releasedate language  star_rating  duration
# 0            Bill Lobely  2008-08-04  English          5.0  02:20:00
# ...
